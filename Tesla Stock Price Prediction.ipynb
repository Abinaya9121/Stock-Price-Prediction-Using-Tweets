# %% [markdown]
# ## Importing neceassry libraries

# %%
import pandas as pd
import re
import string
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline
from wordcloud import WordCloud
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import nltk
from nltk.corpus import stopwords, wordnet
from nltk import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer

from keras.models import Sequential
from keras.layers import LSTM, GRU
from keras.models import load_model
from keras.layers import Dense, Dropout, Bidirectional

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ## Reading the dataset

# %%
df_tsla_tweet = pd.read_csv('/content/drive/MyDrive/sem-8/nlp/NLP Package/tesla_tweets_data.csv')

# %%
df_tsla_tweet
# Out:
#                   id        date  \
# 0       1.212450e+18  02-01-2020
# 1       1.212450e+18  02-01-2020
# 2       1.212450e+18  02-01-2020
# 3       1.212450e+18  02-01-2020
# 4       1.212450e+18  02-01-2020
# ...              ...         ...
# 113736  1.344760e+18  01-01-2021
# 113737  1.344760e+18  01-01-2021
# 113738  1.344760e+18  01-01-2021
# 113739  1.344760e+18  01-01-2021
# 113740  1.344760e+18  01-01-2021
#
#                                                     tweet
# 0       Fun fact: Audi registered more E-Tron's in the...
# 1       That MF TSLA stock at 420.. I watch that shit ...
# 2       @ICannot_Enough And on June 5 th 2019 within 2...
# 3       Tesla is gaining momentum in Taiwan 🇹🇼 @TeslaO...
# 4       @Schuldensuehner Now extrapolate these numbers...
# ...                                                   ...
# 113736  #TSLA whales stepping in for the last day of t...
# 113737  I’ve always wanted to get into investing and t...
# 113738  @RampCapitalLLC $OPEN little buddy told me is ...
# 113739  Fantastic week. Thanks for the huge support in...
# 113740  $TSLA finished 2020 at a pre-split $3,525. Hap...
#
# [113741 rows x 3 columns]

# %%
df_tsla_stock = pd.read_csv('/content/drive/MyDrive/sem-8/nlp/NLP Package/tesla_stock_data.csv')

# %%
df_tsla_stock
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-01-02   28.299999   28.713333   28.114000   28.684000   28.684000
# 1    2020-01-03   29.366667   30.266666   29.128000   29.534000   29.534000
# 2    2020-01-06   29.364668   30.104000   29.333332   30.102667   30.102667
# 3    2020-01-07   30.760000   31.441999   30.224001   31.270666   31.270666
# 4    2020-01-08   31.580000   33.232666   31.215334   32.809334   32.809334
# ..          ...         ...         ...         ...         ...         ...
# 248  2020-12-24  214.330002  222.029999  213.666672  220.589996  220.589996
# 249  2020-12-28  224.836670  227.133331  220.266663  221.229996  221.229996
# 250  2020-12-29  220.333328  223.300003  218.333328  221.996674  221.996674
# 251  2020-12-30  224.000000  232.199997  222.786667  231.593338  231.593338
# 252  2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
#
#         Volume
# 0    142981500
# 1    266677500
# 2    151995000
# 3    268231500
# 4    467164500
# ..         ...
# 248   68596800
# 249   96835800
# 250   68732400
# 251  128538000
# 252  148949700
#
# [253 rows x 7 columns]

# %% [markdown]
# ## Cleaning the dataset

# %%
df_tsla_tweet = df_tsla_tweet.groupby('date').agg({'tweet': ' '.join}).reset_index()

# %% [markdown]
# **Lower case conversion**

# %%
for i in range(df_tsla_tweet.shape[0]):
    df_tsla_tweet['tweet'][i] = df_tsla_tweet['tweet'][i].lower()

# %% [markdown]
# **Remove Punctuation**

# %%
df_tsla_tweet['tweet'] = df_tsla_tweet['tweet'].apply(lambda x: re.sub('[%s]' % re.escape(string.punctuation), '' , x))

# %% [markdown]
# **Remove Stop words**

# %%
stop_words = set(stopwords.words('english'))
stop_words.add('subject')
stop_words.add('http')

# %%
def remove_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in stop_words])

# %%
df_tsla_tweet['tweet'] = df_tsla_tweet['tweet'].apply(lambda x: remove_stopwords(x))

# %%
df_tsla_tweet
# Out:
#            date                                              tweet
# 0    01-01-2020  tsla tesla faces lawsuit claiming racism https...
# 1    01-01-2021  happy new year everyone even tsla short seller...
# 2    01-02-2020  electrekco michelle0728 cannot build tsla with...
# 3    01-03-2020  😳😳😳😳😳 350km electric vehicle would driving 25 ...
# 4    01-04-2020  tesl “earnings” inflated least 200m per q due ...
# ..          ...                                                ...
# 362  31-05-2020  tsla ita เตง ฉันว่าคนละโพดีกว่าคนละเรือ อย่าเค...
# 363  31-07-2020  garyblack00 elonmusk tsla wont need split wait...
# 364  31-08-2020  shanekinguk sincerely hope ev companies surviv...
# 365  31-10-2020  tesla inc tsla price close 20201030 38804 gfil...
# 366  31-12-2020  lol tsla close right bogus spx inclusion day c...
#
# [367 rows x 2 columns]

# %%
df_tsla_tweet['tweet'] = df_tsla_tweet['tweet'].map(lambda x: re.sub(r'http.*', '', x))
df_tsla_tweet['tweet'] = df_tsla_tweet['tweet'].map(lambda x: re.sub(r'[^a-zA-Z#]', ' ', x))
df_tsla_tweet['tweet'] = df_tsla_tweet['tweet'].map(lambda x: x.replace('tesla', ''))
df_tsla_tweet['tweet'] = df_tsla_tweet['tweet'].map(lambda x: x.replace('tsla', ''))
df_tsla_tweet['tweet'] = df_tsla_tweet['tweet'].map(lambda x: x.replace('q', ''))
df_tsla_tweet['tweet'] = df_tsla_tweet['tweet'].map(lambda x: x.replace('#', ''))

# %% [markdown]
# **Lemmatization**

# %%
lemmatizer = WordNetLemmatizer()
def lemmatize_words(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])
df_tsla_tweet['tweet'] = df_tsla_tweet['tweet'].apply(lambda text: lemmatize_words(text))

# %%
df_tsla_tweet
# Out:
#            date                                              tweet
# 0    01-01-2020                       face lawsuit claiming racism
# 1    01-01-2021  happy new year everyone even short seller hell...
# 2    01-02-2020  electrekco michelle cannot build without oil y...
# 3    01-03-2020  km electric vehicle would driving million kilo...
# 4    01-04-2020  tesl earnings inflated least m per due massive...
# ..          ...                                                ...
# 362  31-05-2020  ita anti elon shill going continue call fruad ...
# 363  31-07-2020  garyblack elonmusk wont need split wait two mo...
# 364  31-08-2020  shanekinguk sincerely hope ev company survive ...
# 365  31-10-2020  inc price close gfilche buy pogiboi sandropowe...
# 366  31-12-2020  lol close right bogus spx inclusion day close ...
#
# [367 rows x 2 columns]

# %%
temp_list = []
for i in range(len(df_tsla_tweet['tweet'])):
    tokens = word_tokenize(df_tsla_tweet['tweet'][i])
    temp_list.append(tokens)
df_tsla_tweet['tokenized tweet'] = temp_list

# %%
df_tsla_tweet
# Out:
#            date                                              tweet  \
# 0    01-01-2020                       face lawsuit claiming racism
# 1    01-01-2021  happy new year everyone even short seller hell...
# 2    01-02-2020  electrekco michelle cannot build without oil y...
# 3    01-03-2020  km electric vehicle would driving million kilo...
# 4    01-04-2020  tesl earnings inflated least m per due massive...
# ..          ...                                                ...
# 362  31-05-2020  ita anti elon shill going continue call fruad ...
# 363  31-07-2020  garyblack elonmusk wont need split wait two mo...
# 364  31-08-2020  shanekinguk sincerely hope ev company survive ...
# 365  31-10-2020  inc price close gfilche buy pogiboi sandropowe...
# 366  31-12-2020  lol close right bogus spx inclusion day close ...
#
#                                        tokenized tweet
# 0                    [face, lawsuit, claiming, racism]
# 1    [happy, new, year, everyone, even, short, sell...
# 2    [electrekco, michelle, can, not, build, withou...
# 3    [km, electric, vehicle, would, driving, millio...
# 4    [tesl, earnings, inflated, least, m, per, due,...
# ..                                                 ...
# 362  [ita, anti, elon, shill, going, continue, call...
# 363  [garyblack, elonmusk, wont, need, split, wait,...
# 364  [shanekinguk, sincerely, hope, ev, company, su...
# 365  [inc, price, close, gfilche, buy, pogiboi, san...
# 366  [lol, close, right, bogus, spx, inclusion, day...
#
# [367 rows x 3 columns]

# %%
df_tsla_stock.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df_tsla_stock['Date'] = pd.to_datetime(df_tsla_stock['Date'], dayfirst=True)  
df_tsla_stock = df_tsla_stock[df_tsla_stock['Date'].isin(pd.date_range('2020-01-02', '2021-01-01'))]
df_tsla_stock
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2020-01-02   28.299999   28.713333   28.114000   28.684000   28.684000
# 1   2020-01-03   29.366667   30.266666   29.128000   29.534000   29.534000
# 2   2020-01-06   29.364668   30.104000   29.333332   30.102667   30.102667
# 3   2020-01-07   30.760000   31.441999   30.224001   31.270666   31.270666
# 4   2020-01-08   31.580000   33.232666   31.215334   32.809334   32.809334
# ..         ...         ...         ...         ...         ...         ...
# 248 2020-12-24  214.330002  222.029999  213.666672  220.589996  220.589996
# 249 2020-12-28  224.836670  227.133331  220.266663  221.229996  221.229996
# 250 2020-12-29  220.333328  223.300003  218.333328  221.996674  221.996674
# 251 2020-12-30  224.000000  232.199997  222.786667  231.593338  231.593338
# 252 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
#
#         Volume
# 0    142981500
# 1    266677500
# 2    151995000
# 3    268231500
# 4    467164500
# ..         ...
# 248   68596800
# 249   96835800
# 250   68732400
# 251  128538000
# 252  148949700
#
# [253 rows x 7 columns]

# %% [markdown]
# ## Sentiment Score

# %%
# !pip install vaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 KB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from vaderSentiment) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->vaderSentiment) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->vaderSentiment) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->vaderSentiment) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->vaderSentiment) (1.26.15)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from textblob import TextBlob

# %%
# def calculate_sentiment_textblob(text):
#     testimonial = TextBlob(text)
#     return testimonial.sentiment.polarity

# %%
sentimentAnalyser = SentimentIntensityAnalyzer()

# %%
def calculate_sentiment_vader(text):
    scores = sentimentAnalyser.polarity_scores(text)
    compound_score = scores['compound']
    return compound_score

# %%
df_tsla_tweet['sentiment score'] = df_tsla_tweet['tweet'].apply(calculate_sentiment_vader)
# df_tsla_tweet['sentiment score_tb'] = df_tsla_tweet['tweet'].apply(calculate_sentiment_textblob)

# %%
# df_tsla_tweet = df_tsla_tweet.drop(['sentiment score_tb','sentiment score', 'sentiment score_vader'], axis = 1)

# %%
df_tsla_tweet
# Out:
#            date                                              tweet  \
# 0    01-01-2020                       face lawsuit claiming racism
# 1    01-01-2021  happy new year everyone even short seller hell...
# 2    01-02-2020  electrekco michelle cannot build without oil y...
# 3    01-03-2020  km electric vehicle would driving million kilo...
# 4    01-04-2020  tesl earnings inflated least m per due massive...
# ..          ...                                                ...
# 362  31-05-2020  ita anti elon shill going continue call fruad ...
# 363  31-07-2020  garyblack elonmusk wont need split wait two mo...
# 364  31-08-2020  shanekinguk sincerely hope ev company survive ...
# 365  31-10-2020  inc price close gfilche buy pogiboi sandropowe...
# 366  31-12-2020  lol close right bogus spx inclusion day close ...
#
#                                        tokenized tweet  sentiment score
# 0                    [face, lawsuit, claiming, racism]          -0.7184
# 1    [happy, new, year, everyone, even, short, sell...           0.7328
# 2    [electrekco, michelle, can, not, build, withou...           0.0000
# 3    [km, electric, vehicle, would, driving, millio...           0.0000
# 4    [tesl, earnings, inflated, least, m, per, due,...          -0.7269
# ..                                                 ...              ...
# 362  [ita, anti, elon, shill, going, continue, call...           0.8074
# 363  [garyblack, elonmusk, wont, need, split, wait,...           0.5994
# 364  [shanekinguk, sincerely, hope, ev, company, su...           0.9476
# 365  [inc, price, close, gfilche, buy, pogiboi, san...           0.7717
# 366  [lol, close, right, bogus, spx, inclusion, day...          -0.0072
#
# [367 rows x 4 columns]

# %%
df_tsla_tweet.dtypes
# Out:
# date                object
# tweet               object
# tokenized tweet     object
# sentiment score    float64
# dtype: object

# %%
df_tsla_tweet['date'] = pd.to_datetime(df_tsla_tweet['date'], dayfirst=True)

# %%
df = pd.merge(df_tsla_tweet, df_tsla_stock, how='inner', left_on = 'date', right_on = 'Date')
df
# Out:
#           date                                              tweet  \
# 0   2020-04-01  tesl earnings inflated least m per due massive...
# 1   2020-05-01  dougkass cnbc f b rev b cash v bubble balance ...
# 2   2020-06-01  erpauditor tictoctick higher chance yes discla...
# 3   2020-07-01  level close danahull paying elonmusk musk almo...
# 4   2020-09-01                      loving new setup far vvpr spy
# ..         ...                                                ...
# 248 2020-01-31  concern lack capex guidance stat depreciation ...
# 249 2020-03-31  caranddriver twitter laughably shit im waiting...
# 250 2020-07-31  garyblack elonmusk wont need split wait two mo...
# 251 2020-08-31  shanekinguk sincerely hope ev company survive ...
# 252 2020-12-31  lol close right bogus spx inclusion day close ...
#
#                                        tokenized tweet  sentiment score  \
# 0    [tesl, earnings, inflated, least, m, per, due,...          -0.7269
# 1    [dougkass, cnbc, f, b, rev, b, cash, v, bubble...           0.5267
# 2    [erpauditor, tictoctick, higher, chance, yes, ...           0.8658
# 3    [level, close, danahull, paying, elonmusk, mus...           0.0000
# 4                 [loving, new, setup, far, vvpr, spy]           0.5994
# ..                                                 ...              ...
# 248  [concern, lack, capex, guidance, stat, depreci...          -0.4019
# 249  [caranddriver, twitter, laughably, shit, im, w...          -0.8591
# 250  [garyblack, elonmusk, wont, need, split, wait,...           0.5994
# 251  [shanekinguk, sincerely, hope, ev, company, su...           0.9476
# 252  [lol, close, right, bogus, spx, inclusion, day...          -0.0072
#
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2020-04-01   33.599998   34.263332   31.673332   32.104000   32.104000
# 1   2020-05-01   50.333332   51.518002   45.535999   46.754665   46.754665
# 2   2020-06-01   57.200001   59.933334   56.939999   59.873333   59.873333
# 3   2020-07-01   72.199997   75.688667   72.033333   74.641998   74.641998
# 4   2020-09-01  167.380005  167.496674  156.836670  158.350006  158.350006
# ..         ...         ...         ...         ...         ...         ...
# 248 2020-01-31   42.666668   43.533333   42.167999   43.371334   43.371334
# 249 2020-03-31   33.416668   36.197334   33.133331   34.933334   34.933334
# 250 2020-07-31  101.000000  101.136665   94.732002   95.384003   95.384003
# 251 2020-08-31  148.203339  166.713333  146.703339  166.106674  166.106674
# 252 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
#
#         Volume
# 0    200298000
# 1    487977000
# 2    224092500
# 3    199903500
# 4    269523300
# ..         ...
# 248  235789500
# 249  266572500
# 250  183123000
# 251  355123200
# 252  148949700
#
# [253 rows x 11 columns]

# %%
raw_df = df.copy()

# %%
df = df[['Date','High','Low','Open','Close','Adj Close','Volume','sentiment score']]

# %%
df
# Out:
#           Date        High         Low        Open       Close   Adj Close  \
# 0   2020-04-01   34.263332   31.673332   33.599998   32.104000   32.104000
# 1   2020-05-01   51.518002   45.535999   50.333332   46.754665   46.754665
# 2   2020-06-01   59.933334   56.939999   57.200001   59.873333   59.873333
# 3   2020-07-01   75.688667   72.033333   72.199997   74.641998   74.641998
# 4   2020-09-01  167.496674  156.836670  167.380005  158.350006  158.350006
# ..         ...         ...         ...         ...         ...         ...
# 248 2020-01-31   43.533333   42.167999   42.666668   43.371334   43.371334
# 249 2020-03-31   36.197334   33.133331   33.416668   34.933334   34.933334
# 250 2020-07-31  101.136665   94.732002  101.000000   95.384003   95.384003
# 251 2020-08-31  166.713333  146.703339  148.203339  166.106674  166.106674
# 252 2020-12-31  239.573334  230.373337  233.330002  235.223328  235.223328
#
#         Volume  sentiment score
# 0    200298000          -0.7269
# 1    487977000           0.5267
# 2    224092500           0.8658
# 3    199903500           0.0000
# 4    269523300           0.5994
# ..         ...              ...
# 248  235789500          -0.4019
# 249  266572500          -0.8591
# 250  183123000           0.5994
# 251  355123200           0.9476
# 252  148949700          -0.0072
#
# [253 rows x 8 columns]

# %% [markdown]
# ## Prediction without sentiment scores LSTM

# %%
X_1 = df.drop(['Date', 'Adj Close','sentiment score'], axis = 1)
y_1 = df.iloc[:, 4:5]

# %%
# X = df[['sentiment score']]

# %%
scaler = MinMaxScaler()
X_normalized_1 = scaler.fit_transform(X_1)
y_normalized_1 = scaler.fit_transform(y_1)

i_split = int(len(df) * 0.9)

X_train_1 = X_normalized_1[:i_split, :]
y_train_1 = y_normalized_1[:i_split, :]
X_test_1 = X_normalized_1[i_split:,:]
y_test_1 = y_normalized_1[i_split:,:]

# %%
#Reshaping the train data to make it as input for LTSM layer input_shape(batchzise,timesteps,input_dim)
X_train_new_1 = np.reshape(X_train_1,(X_train_1.shape[0],X_train_1.shape[1],1))

# %%
# model_1 = Sequential()

# model_1.add(LSTM(units = 5,kernel_initializer='glorot_uniform',return_sequences=True,input_shape=(X_train_new_1.shape[1],1)))

# model_1.add(LSTM(units = 2,kernel_initializer='glorot_uniform'))

# model_1.add(Dense(units=1))

# %%
# model_1.compile(optimizer = 'adam', loss = 'mean_squared_error')
# model_1.fit(X_train_1, y_train_1, batch_size = 10, epochs = 10)
# Out:
# Epoch 1/10
# 23/23 [==============================] - 8s 8ms/step - loss: 0.2539
# Epoch 2/10
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1928
# Epoch 3/10
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1513
# Epoch 4/10
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1186
# Epoch 5/10
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0943
# Epoch 6/10
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0759
# Epoch 7/10
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0642
# Epoch 8/10
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0568
# Epoch 9/10
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0508
# Epoch 10/10
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0441

# %%
model_1.save('/content/drive/MyDrive/sem-8/nlp/NLP Package/model_1.h5')

# %%
model_1 = load_model('/content/drive/MyDrive/sem-8/nlp/NLP Package/model_1.h5')

# %%
X_test_new_1 = np.reshape(X_test_1,(X_test_1.shape[0],X_test_1.shape[1],1))
predicted_value_1 = model_1.predict(X_test_new_1)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0ad1ef03a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 815ms/step

# %%
y_test_1
# Out:
# array([[0.58481339],
#        [0.55090254],
#        [0.52693763],
#        [0.93372549],
#        [0.0693909 ],
#        [0.13870286],
#        [0.14959286],
#        [0.2046427 ],
#        [0.35928112],
#        [0.54753991],
#        [0.53453126],
#        [0.93735659],
#        [0.08827868],
#        [0.04449139],
#        [0.13282056],
#        [0.22688998],
#        [0.35561219],
#        [0.56323231],
#        [0.49855232],
#        [0.78202664],
#        [0.98280783],
#        [0.09136032],
#        [0.0513967 ],
#        [0.33770009],
#        [0.67265321],
#        [1.        ]])

# %%
predicted_value_1
# Out:
# array([[0.43609256],
#        [0.4191121 ],
#        [0.4118396 ],
#        [0.49532753],
#        [0.30114204],
#        [0.31655508],
#        [0.315907  ],
#        [0.3269871 ],
#        [0.37004933],
#        [0.41781723],
#        [0.41117758],
#        [0.49236923],
#        [0.31152233],
#        [0.2926134 ],
#        [0.32551956],
#        [0.3367503 ],
#        [0.3675052 ],
#        [0.42031384],
#        [0.40774953],
#        [0.47547668],
#        [0.49913335],
#        [0.30481386],
#        [0.29657173],
#        [0.3691535 ],
#        [0.4444496 ],
#        [0.5047485 ]], dtype=float32)

# %%
plt.figure(figsize=(7,3))
plt.plot(y_test_1,'red',label='Real Prices')
plt.plot(predicted_value_1,'blue',label='Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Prices')
plt.title('Real vs Predicted Prices')
plt.legend(loc='best', fontsize=7)

# %%
print("MAE: ", mean_absolute_error(y_test_1, predicted_value_1))
print("RMSE: ", np.sqrt(mean_squared_error(y_test_1, predicted_value_1)))
print("R2 Score: ", r2_score(y_test_1, predicted_value_1))
# Out:
# MAE:  0.2024769927889017
# RMSE:  0.2421389722302668
# R2 Score:  0.3738655840268096

# %% [markdown]
# ## Prediction with sentiment scores using GRU

# %%
X_2 = df.drop(['Date', 'Adj Close'], axis = 1)
y_2 = df.iloc[:, 4:5]

# %%
# X = df[['sentiment score']]

# %%
scaler = MinMaxScaler()
X_normalized_2 = scaler.fit_transform(X_2)
y_normalized_2 = scaler.fit_transform(y_2)

i_split = int(len(df) * 0.9)

X_train_2 = X_normalized_2[:i_split, :]
y_train_2 = y_normalized_2[:i_split, :]
X_test_2 = X_normalized_2[i_split:,:]
y_test_2 = y_normalized_2[i_split:,:]

# %%
#Reshaping the train data to make it as input for LTSM layer input_shape(batchzise,timesteps,input_dim)
X_train_new_2 = np.reshape(X_train_2,(X_train_2.shape[0],X_train_2.shape[1],1))

# %%
# model_2 = Sequential()
# model_2.add(GRU(units=5, return_sequences = True, input_shape = (X_train_new_2.shape[1],1)))  # 256, return_sequences = True
# model_2.add(GRU(units=3, recurrent_dropout = 0.2)) #, return_sequences = True
# model_2.add(Dense(units=1))

# %%
# model_2.compile(optimizer = 'adam',loss = 'mean_squared_error')
# history_2 = model_2.fit(X_train_2, y_train_2, batch_size = 10, epochs = 10)
# Out:
# Epoch 1/10
# 23/23 [==============================] - 6s 10ms/step - loss: 0.1900
# Epoch 2/10
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0988
# Epoch 3/10
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0552
# Epoch 4/10
# 23/23 [==============================] - 0s 11ms/step - loss: 0.0446
# Epoch 5/10
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0378
# Epoch 6/10
# 23/23 [==============================] - 0s 11ms/step - loss: 0.0298
# Epoch 7/10
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0228
# Epoch 8/10
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0172
# Epoch 9/10
# 23/23 [==============================] - 0s 11ms/step - loss: 0.0094
# Epoch 10/10
# 23/23 [==============================] - 0s 11ms/step - loss: 0.0050

# %%
pyplot.plot(history_2.history['loss'], label='train')
pyplot.legend()
pyplot.show()

# %%
model_2.save('/content/drive/MyDrive/sem-8/nlp/NLP Package/model_2.h5')

# %%
model_2 = load_model('/content/drive/MyDrive/sem-8/nlp/NLP Package/model_2.h5')

# %%
X_test_new_2 = np.reshape(X_test_2,(X_test_2.shape[0], X_test_2.shape[1],1))
predicted_value_2 = model_2.predict(X_test_new_2)
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
y_test_2
# Out:
# array([[0.58481339],
#        [0.55090254],
#        [0.52693763],
#        [0.93372549],
#        [0.0693909 ],
#        [0.13870286],
#        [0.14959286],
#        [0.2046427 ],
#        [0.35928112],
#        [0.54753991],
#        [0.53453126],
#        [0.93735659],
#        [0.08827868],
#        [0.04449139],
#        [0.13282056],
#        [0.22688998],
#        [0.35561219],
#        [0.56323231],
#        [0.49855232],
#        [0.78202664],
#        [0.98280783],
#        [0.09136032],
#        [0.0513967 ],
#        [0.33770009],
#        [0.67265321],
#        [1.        ]])

# %%
predicted_value_2
# Out:
# array([[0.59934336],
#        [0.5465284 ],
#        [0.48740274],
#        [0.77373415],
#        [0.10009848],
#        [0.14454791],
#        [0.14603685],
#        [0.18533011],
#        [0.3626907 ],
#        [0.51002485],
#        [0.5242682 ],
#        [0.717428  ],
#        [0.13289593],
#        [0.06779353],
#        [0.19943994],
#        [0.22372852],
#        [0.3578836 ],
#        [0.5176073 ],
#        [0.4719192 ],
#        [0.7191368 ],
#        [0.7652244 ],
#        [0.1168295 ],
#        [0.08764495],
#        [0.3465125 ],
#        [0.5755729 ],
#        [0.79281205]], dtype=float32)

# %%
plt.figure(figsize=(7,3))
plt.plot(y_test_2,'red',label='Real Prices')
plt.plot(predicted_value_2,'blue',label='Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Prices')
plt.title('Real vs Predicted Prices')
plt.legend(loc='best', fontsize=7)

# %%
print("MAE: ", mean_absolute_error(y_test_2, predicted_value_2))
print("RMSE: ", np.sqrt(mean_squared_error(y_test_2, predicted_value_2)))
print("R2 Score: ", r2_score(y_test_2, predicted_value_2))
# Out:
# MAE:  0.05447957632229823
# RMSE:  0.08640545733816889
# R2 Score:  0.920270226037926

# %% [markdown]
# ## Predcition with sentiment score LSTM

# %%
X_3 = df.drop(['Date', 'Adj Close'], axis = 1)
y_3 = df.iloc[:, 4:5]

# %%
# X = df[['sentiment score']]

# %%
scaler = MinMaxScaler()
X_normalized_3 = scaler.fit_transform(X_3)
y_normalized_3 = scaler.fit_transform(y_3)

i_split = int(len(df) * 0.9)

X_train_3 = X_normalized_3[:i_split, :]
y_train_3 = y_normalized_3[:i_split, :]
X_test_3 = X_normalized_3[i_split:,:]
y_test_3 = y_normalized_3[i_split:,:]

# %%
#Reshaping the train data to make it as input for LTSM layer input_shape(batchzise,timesteps,input_dim)
X_train_new_3 = np.reshape(X_train_3,(X_train_3.shape[0],X_train_3.shape[1],1))

# %%
model_3 = Sequential()

model_3.add(LSTM(units = 5,kernel_initializer='glorot_uniform',return_sequences=True,input_shape=(X_train_new_3.shape[1],1)))

model_3.add(LSTM(units = 2,kernel_initializer='glorot_uniform'))

model_3.add(Dense(units = 1))

# %%
model_3.compile(optimizer = 'adam', loss = 'mean_squared_error')
model_3.fit(X_train_3, y_train_3, batch_size = 10, epochs = 10)
# Out:
# Epoch 1/10
# 23/23 [==============================] - 4s 8ms/step - loss: 0.1048
# Epoch 2/10
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0574
# Epoch 3/10
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0392
# Epoch 4/10
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0318
# Epoch 5/10
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0249
# Epoch 6/10
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0171
# Epoch 7/10
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0099
# Epoch 8/10
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0046
# Epoch 9/10
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0020
# Epoch 10/10
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0013

# %%
model_3.save('/content/drive/MyDrive/sem-8/nlp/NLP Package/model_3.h5')

# %%
model_3 = load_model('/content/drive/MyDrive/sem-8/nlp/NLP Package/model_3.h5')

# %%
X_test_new_3 = np.reshape(X_test_3,(X_test_3.shape[0], X_test_3.shape[1],1))
predicted_value_3 = model_3.predict(X_test_new_3)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
y_test_3
# Out:
# array([[0.58481339],
#        [0.55090254],
#        [0.52693763],
#        [0.93372549],
#        [0.0693909 ],
#        [0.13870286],
#        [0.14959286],
#        [0.2046427 ],
#        [0.35928112],
#        [0.54753991],
#        [0.53453126],
#        [0.93735659],
#        [0.08827868],
#        [0.04449139],
#        [0.13282056],
#        [0.22688998],
#        [0.35561219],
#        [0.56323231],
#        [0.49855232],
#        [0.78202664],
#        [0.98280783],
#        [0.09136032],
#        [0.0513967 ],
#        [0.33770009],
#        [0.67265321],
#        [1.        ]])

# %%
predicted_value_3
# Out:
# array([[0.6167145 ],
#        [0.54755044],
#        [0.55820286],
#        [0.88413596],
#        [0.06263067],
#        [0.16279568],
#        [0.14229643],
#        [0.19153632],
#        [0.339948  ],
#        [0.5746816 ],
#        [0.51188153],
#        [0.89649993],
#        [0.15460368],
#        [0.01166089],
#        [0.1590752 ],
#        [0.22868648],
#        [0.3208661 ],
#        [0.58651584],
#        [0.53824794],
#        [0.7929032 ],
#        [0.9070959 ],
#        [0.0571174 ],
#        [0.01192393],
#        [0.35636842],
#        [0.68944293],
#        [0.9228729 ]], dtype=float32)

# %%
plt.figure(figsize=(7,3))
plt.plot(y_test_3,'red',label='Real Prices')
plt.plot(predicted_value_3,'blue',label='Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Prices')
plt.title('Real vs Predicted Prices')
plt.legend(loc='best', fontsize=7)

# %%
print("MAE: ", mean_absolute_error(y_test_3, predicted_value_3))
print("RMSE: ", np.sqrt(mean_squared_error(y_test_3, predicted_value_3)))
print("R2 Score: ", r2_score(y_test_3, predicted_value_3))
# Out:
# MAE:  0.029814083705501884
# RMSE:  0.03576861876976797
# R2 Score:  0.9863371114371212

# %% [markdown]
# ## Time Series LSTM

# %%
data = df.drop(['Date', 'Adj Close'], axis = 1)
dataset = data.values 

training_data_length = math.ceil(len(dataset) * 0.9)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

# %%
train_data = scaled_data[:training_data_length, :]
x_train = [] 
y_train = [] 

for i in range(10, len(train_data)):
  x_train.append(train_data[i-10:i, 0])
  y_train.append(train_data[i, 0])

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# model = Sequential()
# model.add(LSTM(5, return_sequences=True, input_shape=(x_train.shape[1],1)))
# model.add(LSTM(3, return_sequences=False))
# model.add(Dense(1))

model = Sequential()

model.add(LSTM(units = 128,kernel_initializer='glorot_uniform',return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units=75,kernel_initializer='glorot_uniform',return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50,kernel_initializer='glorot_uniform'))
model.add(Dropout(0.2))

model.add(Dense(units=1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(x_train, y_train, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 22/22 [==============================] - 8s 28ms/step - loss: 0.0770
# Epoch 2/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0644
# Epoch 3/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0613
# Epoch 4/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0524
# Epoch 5/100
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0533
# Epoch 6/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0504
# Epoch 7/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0521
# Epoch 8/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0478
# Epoch 9/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0449
# Epoch 10/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0416
# Epoch 11/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0447
# Epoch 12/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0414
# Epoch 13/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0426
# Epoch 14/100
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0455
# Epoch 15/100
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0416
# Epoch 16/100
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0432
# Epoch 17/100
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0400
# Epoch 18/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0401
# Epoch 19/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0389
# Epoch 20/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0397
# Epoch 21/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0449
# Epoch 22/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0445
# Epoch 23/100
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0385
# Epoch 24/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0411
# Epoch 25/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0424
# Epoch 26/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0473
# Epoch 27/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0412
# Epoch 28/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0406
# Epoch 29/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0379
# Epoch 30/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0358
# Epoch 31/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0403
# Epoch 32/100
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0365
# Epoch 33/100
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0363
# Epoch 34/100
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0367
# Epoch 35/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0363
# Epoch 36/100
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0368
# Epoch 37/100
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0389
# Epoch 38/100
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0375
# Epoch 39/100
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0378
# Epoch 40/100
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0365
# Epoch 41/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0358
# Epoch 42/100
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0358
# Epoch 43/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0351
# Epoch 44/100
# 22/22 [==============================] - 1s 25ms/step - loss: 0.0338
# Epoch 45/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0340
# Epoch 46/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0338
# Epoch 47/100
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0363
# Epoch 48/100
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0362
# Epoch 49/100
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0353
# Epoch 50/100
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0358
# Epoch 51/100
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0352
# Epoch 52/100
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0359
# Epoch 53/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0341
# Epoch 54/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0325
# Epoch 55/100
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0360
# Epoch 56/100
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0357
# Epoch 57/100
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0358
# Epoch 58/100
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0356
# Epoch 59/100
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0317
# Epoch 60/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.0325
# Epoch 61/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0346
# Epoch 62/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0346
# Epoch 63/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0343
# Epoch 64/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0370
# Epoch 65/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0344
# Epoch 66/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0331
# Epoch 67/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0326
# Epoch 68/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0347
# Epoch 69/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0313
# Epoch 70/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0324
# Epoch 71/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0334
# Epoch 72/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0319
# Epoch 73/100
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0343
# Epoch 74/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0332
# Epoch 75/100
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0345
# Epoch 76/100
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0333
# Epoch 77/100
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0333
# Epoch 78/100
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0316
# Epoch 79/100
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0317
# Epoch 80/100
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0303
# Epoch 81/100
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0338
# Epoch 82/100
# 22/22 [==============================] - 1s 33ms/step - loss: 0.0364
# Epoch 83/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0322
# Epoch 84/100
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0318
# Epoch 85/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0331
# Epoch 86/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0335
# Epoch 87/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0320
# Epoch 88/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0338
# Epoch 89/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0330
# Epoch 90/100
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0326
# Epoch 91/100
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0319
# Epoch 92/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0315
# Epoch 93/100
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0320
# Epoch 94/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0309
# Epoch 95/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0328
# Epoch 96/100
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0321
# Epoch 97/100
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0391
# Epoch 98/100
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0326
# Epoch 99/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0314
# Epoch 100/100
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0331

# %%
model.save('/content/drive/MyDrive/sem-8/nlp/NLP Package/model_4.h5')

# %%
model = load_model('/content/drive/MyDrive/sem-8/nlp/NLP Package/model_4.h5')

# %%
test_data = scaled_data[training_data_length - 10:, :]

x_test = []
y_test = scaled_data[training_data_length: , 0]

for i in range(10, len(test_data)):
  x_test.append(test_data[i - 10: i, 0])

# %%
x_test = np.array(x_test)

# %%
y_test
# Out:
# array([0.54427138, 0.52940663, 0.94148157, 0.05799783, 0.12492081,
#        0.13489341, 0.18977403, 0.35435625, 0.54492994, 0.52855987,
#        0.9234494 , 0.07715272, 0.03505773, 0.14581307, 0.21413786,
#        0.34759184, 0.55344427, 0.5121427 , 0.82607553, 0.96531544,
#        0.07781757, 0.04330864, 0.34878666, 0.65726274, 1.        ])

# %%
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
predictions = model.predict(x_test)
# predictions = scaler.inverse_transform(predictions) #unscaling values
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
predictions
# Out:
# array([[0.56960285],
#        [0.6466485 ],
#        [0.41255173],
#        [0.05307395],
#        [0.07503441],
#        [0.14650896],
#        [0.2702886 ],
#        [0.418017  ],
#        [0.5352866 ],
#        [0.58327955],
#        [0.6214736 ],
#        [0.375955  ],
#        [0.07778631],
#        [0.12092124],
#        [0.23705563],
#        [0.38884014],
#        [0.51695496],
#        [0.574466  ],
#        [0.6360565 ],
#        [0.394867  ],
#        [0.04771814],
#        [0.06589798],
#        [0.14566894],
#        [0.27532816],
#        [0.37911582]], dtype=float32)

# %%
y_test
# Out:
# array([0.54427138, 0.52940663, 0.94148157, 0.05799783, 0.12492081,
#        0.13489341, 0.18977403, 0.35435625, 0.54492994, 0.52855987,
#        0.9234494 , 0.07715272, 0.03505773, 0.14581307, 0.21413786,
#        0.34759184, 0.55344427, 0.5121427 , 0.82607553, 0.96531544,
#        0.07781757, 0.04330864, 0.34878666, 0.65726274, 1.        ])

# %%
print("MAE: ", mean_absolute_error(y_test, predictions))
print("RMSE: ", np.sqrt(mean_squared_error(y_test, predictions)))
print("R2 Score: ", r2_score(y_test, predictions))
# Out:
# MAE:  0.15187748864837702
# RMSE:  0.23969540534685457
# R2 Score:  0.4183650160541903
